# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set variables
c_data_list = []
set_no = 1
rec_no = 1
num_of_set = 50
units = "imperial"

print("Beginning Data Retrieval")
print("-----------------------------")

# Put city data into the list
for city in cities:
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units={units}"
    response = requests.get(url).json()
    try:
        c_data_list.append({"City" : city,
                            "Lat" : response["coord"]["lat"],
                            "Lng" : response["coord"]["lon"],
                            "Max Temp" : response["main"]["temp_max"],
                            "Humidity" : response["main"]["humidity"],
                            "Cloudiness" : response["clouds"]["all"],
                            "Wind Speed" : response["wind"]["speed"],
                            "Country" : response["sys"]["country"],
                            "Date" : response["dt"]})
        print(f"Processing Record {rec_no} of Set {set_no} | {city}")
        if (len(c_data_list)) % num_of_set == 0:
            rec_no = 1
            set_no += 1
        
        else:
            rec_no += 1
        
    except KeyError:
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | huilong
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | urumqi
# Processing Record 8 of Set 1 | georgetown
# City not found. Skipping...
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | caucaia
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | namatanai
# Processing Record 14 of Set 1 | mariapocs
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 17 of Set 1 | sol-iletsk
# Processing Record 18 of Set 1 | itarema
# Processing Record 19 of Set 1 | bukachacha
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | suntar
# Processing Record 24 of Set 1 | talnakh
# Processing Record 25 of Set 1 | devonport
# Processing Record 26 of Set 1 | orlovka
# Processing Record 27 of Set 1 | naze
# Processing Record 28 of Set 1 | palmer
# Processing Record 29 of Set 1 | novaya igirma
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | saskylakh
# Processing Record 33 of Set 1 | esperance
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | fallon
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | katangli
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 40 of Set 1 | arvika
# Processing Record 41 of Set 1 | iguai
# Processing Record 42 of Set 1 | ginda
# Processing Record 43 of Set 1 | kuli
# Processing Record 44 of Set 1 | lagoa
# Processing Record 45 of Set 1 | monroe
# Processing Record 46 of Set 1 | mehamn
# City not found. Skipping...
# Processing Record 47 of Set 1 | tigil
# Processing Record 48 of Set 1 | sulangan
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | kilindoni
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | ketchikan
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | half moon bay
# Processing Record 5 of Set 2 | yellowknife
# City not found. Skipping...
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | kavaratti
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | wexford
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 46 of Set 4 | mount isa
# City not found. Skipping...
# Processing Record 47 of Set 4 | ko samui
# Processing Record 48 of Set 4 | san quintin
# City not found. Skipping...
# Processing Record 49 of Set 4 | sitka
# Processing Record 50 of Set 4 | walvis bay
# Processing Record 1 of Set 5 | mao
# City not found. Skipping...
# Processing Record 2 of Set 5 | fukue
# Processing Record 3 of Set 5 | yerbogachen
# Processing Record 4 of Set 5 | plettenberg bay
# Processing Record 5 of Set 5 | fort nelson
# Processing Record 6 of Set 5 | shingu
# Processing Record 7 of Set 5 | heinola
# Processing Record 8 of Set 5 | nanortalik
# Processing Record 9 of Set 5 | aloleng
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 of Set 5 | kasane
# Processing Record 11 of Set 5 | waipawa
# Processing Record 12 of Set 5 | port hardy
# Processing Record 13 of Set 5 | zeya
# Processing Record 14 of Set 5 | saint george
# Processing Record 15 of Set 5 | ust-tsilma
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | luancheng
# Processing Record 18 of Set 5 | marawi
# Processing Record 19 of Set 5 | pachino
# Processing Record 20 of Set 5 | aklavik
# Processing Record 21 of Set 5 | vardo
# Processing Record 22 of Set 5 | bilma
# Processing Record 23 of Set 5 | puerto quijarro
# Processing Record 24 of Set 5 | ayios nikolaos
# Processing Record 25 of Set 5 | araouane
# Processing Record 26 of Set 5 | ancud
# Processing Record 27 of Set 5 | kandrian
# Processing Record 28 of Set 5 | san cristobal
# Processing Record 29 of Set 5 | shelburne
# Processing Record 30 of Set 5 | kruisfontein
# Processing Record 31 of Set 5 | bonthe
# Processing Record 32 of Set 5 | kaohsiung
# Processing Record 33 of Set 5 | keti bandar
# Processing Record 34 of Set 5 | storforshei
# Processing Record 35 of Set 5 | klaksvik
# City not found. Skipping...
# Processing Record 36 of Set 5 | kodiak
# Processing Record 37 of Set 5 | karanganyar
# Processing Record 38 of Set 5 | khor
# Processing Record 39 of Set 5 | podosinovets
# Processing Record 40 of Set 5 | homer
# Processing Record 41 of Set 5 | sinnamary
# Processing Record 42 of Set 5 | seoul
# Processing Record 43 of Set 5 | lashio
# Processing Record 44 of Set 5 | cradock
# Processing Record 45 of Set 5 | leningradskiy
# Processing Record 46 of Set 5 | kushima
# Processing Record 47 of Set 5 | willowmore
# Processing Record 48 of Set 5 | raga
# Processing Record 49 of Set 5 | gat
# Processing Record 50 of Set 5 | tombouctou
# Processing Record 1 of Set 6 | tasiilaq
# Processing Record 2 of Set 6 | yabrud
# Processing Record 3 of Set 6 | nantucket
# Processing Record 4 of Set 6 | abha
# Processing Record 5 of Set 6 | mitsamiouli
# Processing Record 6 of Set 6 | burnie
# Processing Record 7 of Set 6 | kununurra
# Processing Record 8 of Set 6 | pevek
# Processing Record 9 of Set 6 | la ronge
# City not found. Skipping...
# Processing Record 10 of Set 6 | taksimo
# Processing Record 11 of Set 6 | caldwell
# Processing Record 12 of Set 6 | sarkand
# Processing Record 13 of Set 6 | yulara
# Processing Record 14 of Set 6 | port hedland
# Processing Record 15 of Set 6 | baykit
# Processing Record 16 of Set 6 | port augusta
# Processing Record 17 of Set 6 | bathsheba
# Processing Record 18 of Set 6 | sept-iles
# Processing Record 19 of Set 6 | oktyabrskiy
# Processing Record 20 of Set 6 | bagdarin
# Processing Record 21 of Set 6 | tura
# Processing Record 22 of Set 6 | asau
# Processing Record 23 of Set 6 | dunedin
# Processing Record 24 of Set 6 | arraial do cabo
# Processing Record 25 of Set 6 | sedniv
# Processing Record 26 of Set 6 | kamenka
# Processing Record 27 of Set 6 | lata
# Processing Record 28 of Set 6 | russell
# Processing Record 29 of Set 6 | yaan
# Processing Record 30 of Set 6 | barth
# Processing Record 31 of Set 6 | santiago del estero
# City not found. Skipping...
# Processing Record 32 of Set 6 | saurimo
# Processing Record 33 of Set 6 | amarante do maranhao
# Processing Record 34 of Set 6 | magadan
# Processing Record 35 of Set 6 | ipaussu
# Processing Record 36 of Set 6 | tezu
# Processing Record 37 of Set 6 | grindavik
# Processing Record 38 of Set 6 | sabang
# Processing Record 39 of Set 6 | yumen
# Processing Record 40 of Set 6 | krasnoselkup
# Processing Record 41 of Set 6 | coihaique
# Processing Record 42 of Set 6 | torbay
# Processing Record 43 of Set 6 | mahibadhoo
# City not found. Skipping...
# Processing Record 44 of Set 6 | alekseyevka
# Processing Record 45 of Set 6 | upernavik
# Processing Record 46 of Set 6 | balkanabat
# Processing Record 47 of Set 6 | ippy
# Processing Record 48 of Set 6 | michurinsk
# Processing Record 49 of Set 6 | chifeng
# Processing Record 50 of Set 6 | tuatapere
# Processing Record 1 of Set 7 | saldanha
# Processing Record 2 of Set 7 | ugoofaaru
# Processing Record 3 of Set 7 | imbituba
# Processing Record 4 of Set 7 | honningsvag
# Processing Record 5 of Set 7 | langenburg
# Processing Record 6 of Set 7 | angoche
# Processing Record 7 of Set 7 | genhe
# Processing Record 8 of Set 7 | angoram
# Processing Record 9 of Set 7 | riyadh
# Processing Record 10 of Set 7 | namibe
# Processing Record 11 of Set 7 | kendari
# Processing Record 12 of Set 7 | jining
# Processing Record 13 of Set 7 | qiqihar
# Processing Record 14 of Set 7 | saint-francois
# Processing Record 15 of Set 7 | placerville
# Processing Record 16 of Set 7 | marsa matruh
# City not found. Skipping...
# Processing Record 17 of Set 7 | chicama
# Processing Record 18 of Set 7 | nadym
# Processing Record 19 of Set 7 | isiro
# Processing Record 20 of Set 7 | hay river
# Processing Record 21 of Set 7 | lasa
# Processing Record 22 of Set 7 | new norfolk
# Processing Record 23 of Set 7 | salinopolis
# Processing Record 24 of Set 7 | vizianagaram
# Processing Record 25 of Set 7 | machilipatnam
# Processing Record 26 of Set 7 | khani
# Processing Record 27 of Set 7 | tete
# Processing Record 28 of Set 7 | victoria
# Processing Record 29 of Set 7 | payo
# Processing Record 30 of Set 7 | gornozavodsk
# Processing Record 31 of Set 7 | vao
# Processing Record 32 of Set 7 | candolim
# Processing Record 33 of Set 7 | bani walid
# Processing Record 34 of Set 7 | camacha
# Processing Record 35 of Set 7 | pangai
# Processing Record 8 of Set 9 | dudinka
# Processing Record 9 of Set 9 | sisimiut
# Processing Record 10 of Set 9 | lesogorsk
# Processing Record 11 of Set 9 | katsuura
# Processing Record 12 of Set 9 | panaba
# City not found. Skipping...
# Processing Record 13 of Set 9 | poum
# Processing Record 14 of Set 9 | capitan bado
# Processing Record 15 of Set 9 | geraldton
# Processing Record 16 of Set 9 | aykhal
# Processing Record 17 of Set 9 | doka
# Processing Record 18 of Set 9 | gonen
# Processing Record 19 of Set 9 | zalantun
# Processing Record 20 of Set 9 | iquique
# Processing Record 21 of Set 9 | narsaq
# Processing Record 22 of Set 9 | yanam
# Processing Record 23 of Set 9 | paralimni
# Processing Record 24 of Set 9 | guerrero negro
# Processing Record 25 of Set 9 | sambava
# Processing Record 26 of Set 9 | ambovombe
# Processing Record 27 of Set 9 | aitape
# Processing Record 28 of Set 9 | altagracia de orituco
# Processing Record 29 of Set 9 | am timan
# Processing Record 30 of Set 9 | mitu
# Processing Record 31 of Set 9 | coquimbo
# Processing Record 32 of Set 9 | puerto del rosario
# Processing Record 33 of Set 9 | port-cartier
# Processing Record 34 of Set 9 | samarai
# Processing Record 35 of Set 9 | havelock
# Processing Record 36 of Set 9 | cordoba
# Processing Record 37 of Set 9 | camana
# Processing Record 38 of Set 9 | staunton
# Processing Record 39 of Set 9 | airai
# Processing Record 40 of Set 9 | mizdah
# Processing Record 41 of Set 9 | touros
# Processing Record 42 of Set 9 | patacamaya
# Processing Record 43 of Set 9 | portland
# City not found. Skipping...
# Processing Record 44 of Set 9 | yar-sale
# Processing Record 45 of Set 9 | ulychne
# Processing Record 46 of Set 9 | malakal
# Processing Record 47 of Set 9 | isangel
# Processing Record 48 of Set 9 | carutapera
# Processing Record 49 of Set 9 | lompoc
# Processing Record 50 of Set 9 | acarau
# Processing Record 1 of Set 10 | tenenkou
# Processing Record 2 of Set 10 | orbetello
# Processing Record 3 of Set 10 | kostino
# Processing Record 4 of Set 10 | bayir
# Processing Record 5 of Set 10 | shatalovo
# Processing Record 6 of Set 10 | cairns
# Processing Record 7 of Set 10 | pag
# Processing Record 8 of Set 10 | tadine
# Processing Record 9 of Set 10 | caceres
# Processing Record 10 of Set 10 | matiri
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 10 | srandakan
# Processing Record 12 of Set 10 | ust-kuyga
# Processing Record 13 of Set 10 | high level
# Processing Record 14 of Set 10 | sao paulo de olivenca
# Processing Record 15 of Set 10 | neiafu
# Processing Record 16 of Set 10 | srednekolymsk
# Processing Record 17 of Set 10 | yambio
# Processing Record 18 of Set 10 | emba
# Processing Record 19 of Set 10 | nosy varika
# Processing Record 20 of Set 10 | ixtapa
# Processing Record 21 of Set 10 | bom sucesso
# Processing Record 22 of Set 10 | praia da vitoria
# Processing Record 23 of Set 10 | kaduqli
# Processing Record 24 of Set 10 | hami
# Processing Record 25 of Set 10 | ranong
# Processing Record 26 of Set 10 | pisco
# Processing Record 27 of Set 10 | upington
# Processing Record 28 of Set 10 | nerchinskiy zavod
# Processing Record 29 of Set 10 | jiwani
# Processing Record 30 of Set 10 | marsh harbour
# Processing Record 31 of Set 10 | mendi
# Processing Record 32 of Set 10 | kihei
# Processing Record 33 of Set 10 | baniachang
# Processing Record 34 of Set 10 | bowen
# Processing Record 35 of Set 10 | rio grande
# Processing Record 36 of Set 10 | syntul
# Processing Record 37 of Set 10 | saint austell
# Processing Record 38 of Set 10 | kalabo
# Processing Record 39 of Set 10 | moron de la frontera
# Processing Record 40 of Set 10 | jalu
# Processing Record 41 of Set 10 | lucea
# Processing Record 42 of Set 10 | hervey bay
# Processing Record 43 of Set 10 | zatoka
# Processing Record 44 of Set 10 | mayskiy
# City not found. Skipping...
# Processing Record 45 of Set 10 | namikupa
# Processing Record 46 of Set 10 | puno
# Processing Record 47 of Set 10 | husavik
# Processing Record 48 of Set 10 | deputatskiy
# Processing Record 49 of Set 10 | los llanos de aridane
# Processing Record 50 of Set 10 | ahipara
# Processing Record 1 of Set 11 | elko
# Processing Record 2 of Set 11 | ruteng
# Processing Record 3 of Set 11 | rocha
# Processing Record 4 of Set 11 | hailar
# Processing Record 5 of Set 11 | palafrugell
# Processing Record 6 of Set 11 | waingapu
# Processing Record 7 of Set 11 | gimli
# Processing Record 8 of Set 11 | lorengau
# Processing Record 9 of Set 11 | williamsport
# City not found. Skipping...
# Processing Record 10 of Set 11 | mishan
# Processing Record 11 of Set 11 | north platte
# Processing Record 12 of Set 11 | mandera
# Processing Record 13 of Set 11 | gravdal
# Processing Record 14 of Set 11 | balaipungut
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 11 | fulton
# Processing Record 16 of Set 11 | makat
# Processing Record 17 of Set 11 | antofagasta
# Processing Record 18 of Set 11 | qesarya
# Processing Record 19 of Set 11 | jian
# Processing Record 20 of Set 11 | kirakira
# City not found. Skipping...
# Processing Record 21 of Set 11 | laguna
# Processing Record 22 of Set 11 | idil
# Processing Record 23 of Set 11 | pasighat
# Processing Record 24 of Set 11 | skibotn
# Processing Record 25 of Set 11 | bacong
# City not found. Skipping...
# Processing Record 26 of Set 11 | presidencia roque saenz pena
# Processing Record 27 of Set 11 | havoysund
# Processing Record 28 of Set 11 | gushikawa
# Processing Record 29 of Set 11 | omboue
# Processing Record 30 of Set 11 | gasa
# Processing Record 31 of Set 11 | manono
# Processing Record 32 of Set 11 | ambilobe
# Processing Record 33 of Set 11 | sola
# Processing Record 34 of Set 11 | ambon
# Processing Record 35 of Set 11 | roma
# City not found. Skipping...
# Processing Record 36 of Set 11 | lima
# City not found. Skipping...
# Processing Record 37 of Set 11 | shemordan
# Processing Record 38 of Set 11 | biu
# Processing Record 39 of Set 11 | warwick
# Processing Record 40 of Set 11 | palu
# Processing Record 41 of Set 11 | ganzhou
# Processing Record 42 of Set 11 | drumheller
# Processing Record 43 of Set 11 | bamenda
# Processing Record 44 of Set 11 | mossendjo
# Processing Record 45 of Set 11 | mugur-aksy
# Processing Record 46 of Set 11 | pacific grove
# Processing Record 47 of Set 11 | inhambane
# Processing Record 48 of Set 11 | shar
# Processing Record 49 of Set 11 | okato
# Processing Record 50 of Set 11 | almaznyy
# Processing Record 1 of Set 12 | hobyo
# Processing Record 2 of Set 12 | port lincoln
# Processing Record 3 of Set 12 | fairbanks
# Processing Record 4 of Set 12 | palmira
# Processing Record 5 of Set 12 | faya
# Processing Record 6 of Set 12 | port-gentil
# Processing Record 7 of Set 12 | lagos
# Processing Record 8 of Set 12 | ust-koksa
# Processing Record 9 of Set 12 | rawtenstall
# Processing Record 10 of Set 12 | westport
# Processing Record 11 of Set 12 | marystown
# Processing Record 12 of Set 12 | wajima
# Processing Record 13 of Set 12 | novobirilyussy
# Processing Record 14 of Set 12 | nanakuli
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dataframe to store the city data
cities_df = pd.DataFrame(c_data_list)
cities_df.count()
# Out:
# City          564
# Lat           564
# Lng           564
# Max Temp      564
# Humidity      564
# Cloudiness    564
# Wind Speed    564
# Country       564
# Date          564
# dtype: int64

# %%
# Show five cities
cities_df.head()
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   huilong  31.81  121.66     84.00        90         100        1.01
# 1     bluff -46.60  168.33     37.24        80           0        5.97
# 2  hermanus -34.42   19.23     64.99        72           0        7.00
# 3    hobart -42.88  147.33     51.80        57          75       10.29
# 4    bethel  41.37  -73.41     77.00        73           1        4.34
#
#   Country        Date
# 0      CN  1595080799
# 1      NZ  1595080799
# 2      ZA  1595080799
# 3      AU  1595080800
# 4      US  1595080569

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Describe the city data
cities_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  564.000000  564.000000  564.000000  564.000000  564.000000  564.000000
# mean    21.396613   22.246879   71.545106   68.251773   49.994681    7.904096
# std     33.071679   90.579237   14.646945   22.745727   39.724204    5.367141
# min    -54.800000 -179.170000   28.400000    3.000000    0.000000    0.220000
# 25%     -6.297500  -56.022500   61.625000   57.000000    3.000000    4.312500
# 50%     27.660000   29.240000   73.400000   73.000000   40.000000    6.465000
# 75%     49.305000  100.627500   82.000000   85.000000   90.250000   10.290000
# max     78.220000  178.420000  109.400000  100.000000  100.000000   34.450000
#
#                Date
# count  5.640000e+02
# mean   1.595081e+09
# std    6.266392e+01
# min    1.595080e+09
# 25%    1.595081e+09
# 50%    1.595081e+09
# 75%    1.595081e+09
# max    1.595081e+09

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_idx = cities_df.loc[(cities_df.iloc[:, 4] > 100)].index
humidity_idx
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
filtered_df = cities_df.drop(index = humidity_idx)
filtered_df.head()
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   huilong  31.81  121.66     84.00        90         100        1.01
# 1     bluff -46.60  168.33     37.24        80           0        5.97
# 2  hermanus -34.42   19.23     64.99        72           0        7.00
# 3    hobart -42.88  147.33     51.80        57          75       10.29
# 4    bethel  41.37  -73.41     77.00        73           1        4.34
#
#   Country        Date
# 0      CN  1595080799
# 1      NZ  1595080799
# 2      ZA  1595080799
# 3      AU  1595080800
# 4      US  1595080569

# %%
# Extract relevant fields from the data frame
to_csv_df = cities_df.iloc[:, [0, 5, 7, 8, 4, 1, 2, 3, 6]]
to_csv_df.index.name = "City_ID"
# Export the City_Data into a csv

to_csv_df.to_csv(output_data_file)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Get data to make a scatter plot from the city data
latitude = cities_df.iloc[:, 1]
max_temp = cities_df.iloc[:, 3]

# Create a scatter plot - Latitude vs. Max Temperature
plt.scatter(latitude, max_temp, c = max_temp, cmap = "viridis", edgecolors = "black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature ({datetime.today().strftime('%m/%d/%y')})")
plt.savefig("../output_data/max_temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Get humidity data from the city data
humidity = cities_df.iloc[:, 4]

# Create a scatter plot - Latitude vs. Humidity
plt.scatter(latitude, humidity, c = humidity, cmap = "viridis", edgecolors = "black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity ({datetime.today().strftime('%m/%d/%y')})")
plt.savefig("../output_data/humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Get cloudiness from the city data
cloudiness = cities_df.iloc[:, 5]

# Create a scatter plot - Latitude vs. Cloudiness
plt.scatter(latitude, cloudiness, c = cloudiness, cmap = "viridis", edgecolors = "black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness ({datetime.today().strftime('%m/%d/%y')})")
plt.savefig("../output_data/cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Get wind speed from the city data
wind_speed = cities_df.iloc[:, 6]

# Create a scatter plot - Latitude vs. Cloudiness
plt.scatter(latitude, wind_speed, c = wind_speed, cmap = "viridis", edgecolors = "black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed ({datetime.today().strftime('%m/%d/%y')})")
plt.savefig("../output_data/wind_speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_r_plot(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    print(f"The r-squared is: {rvalue**2}")
    regress_values = x_values * slope + intercept
    line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    
    plt.plot(x_values, regress_values, "r-")
    
    return line_eq

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df = cities_df.loc[cities_df.iloc[:, 1] >= 0]
south_df = cities_df.loc[cities_df.iloc[:, 1] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Get latitude and max temperature data on Northern Hemisphere
north_lat = north_df.iloc[:, 1]
north_max_temp = north_df.iloc[:, 3]

# Create a scatter plot with a linear regression - Latitude vs. Max temperature
plt.scatter(north_lat, north_max_temp, c = north_max_temp, cmap = "viridis")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Northern Hemisphere -  Latitude vs. Max Temperature (F)")
plt.annotate(linear_r_plot(north_lat, north_max_temp), (10, 90), fontsize = 15, color = "red", weight = "bold")
plt.savefig("../output_data/northern_max_temp.png")
plt.show()
# Out:
# The r-squared is: 0.4359765283516764

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Get latitude and max temperature data on Southern Hemisphere
south_lat = south_df.iloc[:, 1]
south_max_temp = south_df.iloc[:, 3]

# Create a scatter plot with a linear regression - Latitude vs. Max temperature
plt.scatter(south_lat, south_max_temp, c = south_max_temp, cmap = "viridis")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Southern Hemisphere - Latitude vs. Max Temperature (F)")
plt.annotate(linear_r_plot(south_lat, south_max_temp), (-40, 35), fontsize = 15, color = "red", weight = "bold")
plt.savefig("../output_data/southern_max_temp.png")
plt.show()
# Out:
# The r-squared is: 0.5389752206962874

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Get humidity data on Northern Hemisphere
north_humidity = north_df.iloc[:, 4]

# Create a scatter plot with a linear regression - Latitude vs. Humidity
plt.scatter(north_lat, north_humidity, c = north_humidity, cmap = "viridis")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere - Latitude vs. Humidity (%)")
plt.annotate(linear_r_plot(north_lat, north_humidity), (10, 85), fontsize = 15, color = "red", weight = "bold")
plt.savefig("../output_data/northern_humidity.png")
plt.show()
# Out:
# The r-squared is: 0.0035867569738802793

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Get humidity data on Southern Hemisphere
south_humidity = south_df.iloc[:, 4]

# Create a scatter plot with a linear regression - Latitude vs. Humidity
plt.scatter(south_lat, south_humidity, c = south_humidity, cmap = "viridis")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere - Latitude vs. Humidity (%)")
plt.annotate(linear_r_plot(south_lat, south_humidity), (-50, 85), fontsize = 15, color = "red", weight = "bold")
plt.savefig("../output_data/southern_humidity.png")
plt.show()
# Out:
# The r-squared is: 0.0019310473903841985

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Get cloudiness data on Northern Hemisphere
north_cloudiness = north_df.iloc[:, 5]

# Create a scatter plot with a linear regression - Latitude vs. Cloudiness
plt.scatter(north_lat, north_cloudiness, c = north_cloudiness, cmap = "viridis")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere - Latitude vs. Cloudiness (%)")
plt.annotate(linear_r_plot(north_lat, north_cloudiness), (10, 60), fontsize = 15, color = "red", weight = "bold")
plt.savefig("../output_data/northern_cloudiness.png")
plt.show()
# Out:
# The r-squared is: 0.005649529242495661

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Get cloudiness data on Southern Hemisphere
south_cloudiness = south_df.iloc[:, 5]

# Create a scatter plot with a linear regression - Latitude vs. Cloudiness
plt.scatter(south_lat, south_cloudiness, c = south_cloudiness, cmap = "viridis")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere - Latitude vs. Cloudiness (%)")
plt.annotate(linear_r_plot(south_lat, south_cloudiness), (-50, 60), fontsize = 15, color = "red", weight = "bold")
plt.savefig("../output_data/southern_cloudiness.png")
plt.show()
# Out:
# The r-squared is: 0.0073951367965076455

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Get wind speed data on Northern Hemisphere
north_wind_speed = north_df.iloc[:, 6]

# Create a scatter plot with a linear regression - Latitude vs. Cloudiness
plt.scatter(north_lat, north_wind_speed, c = north_wind_speed, cmap = "viridis")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere - Latitude vs. Wind Speed (mph)")
plt.annotate(linear_r_plot(north_lat, north_wind_speed), (10, 15), fontsize = 15, color = "red", weight = "bold")
plt.savefig("../output_data/northern_wind_speed.png")
plt.show()
# Out:
# The r-squared is: 0.0005496335926640506

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Get wind speed data on Southern Hemisphere
south_wind_speed = south_df.iloc[:, 6]

# Create a scatter plot with a linear regression - Latitude vs. Cloudiness
plt.scatter(south_lat, south_wind_speed, c = south_wind_speed, cmap = "viridis")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere - Latitude vs. Wind Speed (mph)")
plt.annotate(linear_r_plot(south_lat, south_wind_speed), (-50, 10), fontsize = 15, color = "red", weight = "bold")
plt.savefig("../output_data/southern_wind_speed.png")
plt.show()
# Out:
# The r-squared is: 0.004296902573192426

# %% [markdown]
# ## Result

# %% [markdown]
# * The higher or the lower latitude is, the colder temperature is. The closer to the equator it is, the hotter it is.
#
#
# * I wasn't able to find any correlation between latitude and wind speed, humidity, cloudiness.
#
#
# * I suppose preciptation per city or comparing inland cities with waterfront cities would help to find out the correlation with humidity.
